# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'B': [50,40,30,20,10]})

# %%
df.ewm(com=0.9).mean()
# Out:
#            B
# 0  50.000000
# 1  43.214286
# 2  35.432300
# 3  26.879444
# 4  17.778490

# %%
df.ewm(alpha=2 / 5).mean()
# Out:
#            B
# 0  50.000000
# 1  43.750000
# 2  36.734694
# 3  29.044118
# 4  20.784178
